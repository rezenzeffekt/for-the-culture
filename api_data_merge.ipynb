# %%
# imports
import pandas as pd
from functions import *
ds = pd.read_csv('data/d_t100_8c_songs.csv', header=0, index_col=False)
s01 = pd.read_csv('data/songs_01.csv', header=0, index_col=False)
s02 = pd.read_csv('data/songs_02.csv', header=0, index_col=False)
s03 = pd.read_csv('data/songs_03.csv', header=0, index_col=False)
s04 = pd.read_csv('data/songs_04.csv', header=0, index_col=False)
s05 = pd.read_csv('data/songs_05.csv', header=0, index_col=False)
s06 = pd.read_csv('data/songs_06.csv', header=0, index_col=False)
s07 = pd.read_csv('data/songs_07.csv', header=0, index_col=False)
s08 = pd.read_csv('data/songs_08.csv', header=0, index_col=False)
s09 = pd.read_csv('data/songs_09.csv', header=0, index_col=False)
s10 = pd.read_csv('data/songs_10.csv', header=0, index_col=False)
s11 = pd.read_csv('data/songs_11.csv', header=0, index_col=False)
s12 = pd.read_csv('data/songs_12.csv', header=0, index_col=False)
s13 = pd.read_csv('data/songs_13.csv', header=0, index_col=False)
s14 = pd.read_csv('data/songs_14.csv', header=0, index_col=False)
s15 = pd.read_csv('data/songs_15.csv', header=0, index_col=False)
s16 = pd.read_csv('data/songs_16.csv', header=0, index_col=False)
s17 = pd.read_csv('data/songs2_01.csv', header=0, index_col=False)
s18 = pd.read_csv('data/songs2_02.csv', header=0, index_col=False)
s19 = pd.read_csv('data/songs2_03.csv', header=0, index_col=False)
s20 = pd.read_csv('data/songs2_04.csv', header=0, index_col=False)
s21 = pd.read_csv('data/songs2_05.csv', header=0, index_col=False)
s22 = pd.read_csv('data/songs2_06.csv', header=0, index_col=False)

# %%
s01.head(3)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.720   0.763    9    -4.068     0       0.0523         0.406
# 1         0.676   0.929   10    -3.194     1       0.0458         0.186
# 2         0.773   0.623    6    -6.173     0       0.0377         0.220
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000     0.180    0.742  101.965  audio_features
# 1          0.000405     0.121    0.157   97.019  audio_features
# 2          0.000000     0.389    0.714  129.962  audio_features
#
#                        id                                   uri  \
# 0  5knuzwU65gJK7IF5yJsuaW  spotify:track:5knuzwU65gJK7IF5yJsuaW
# 1  0JiVRyTJcJnmlwCZ854K4p  spotify:track:0JiVRyTJcJnmlwCZ854K4p
# 2  2nYpbaLykC2cjU8Yt5KF1v  spotify:track:2nYpbaLykC2cjU8Yt5KF1v
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5knuzwU65gJK...
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18710 entries, 0 to 18709
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     18710 non-null  object
#  1   artist    18710 non-null  object
#  2   track_id  18710 non-null  object
# dtypes: object(3)
# memory usage: 438.6+ KB

# %%
check = pd.concat([s01, s02, s03, s04, s05, s06, s07, s08, s09, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22], ignore_index=True)

# %%
check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18710 entries, 0 to 18709
# Data columns (total 19 columns):
#  #   Column                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                             --------------  -----
#  0   danceability                                                                                                                       18710 non-null  float64
#  1   energy                                                                                                                             18710 non-null  float64
#  2   key                                                                                                                                18710 non-null  int64
# ...

# %%
check.tail(3)
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 18707         0.673   0.842    1   -10.171     0       0.0304       0.00319
# 18708         0.763   0.419    8    -9.916     0       0.0529       0.38300
# 18709         0.658   0.678    1    -4.407     1       0.0580       0.30300
#
#        instrumentalness  liveness  valence    tempo            type  \
# 18707          0.000011    0.9520    0.806  134.802  audio_features
# 18708          0.001690    0.0732    0.335   92.044  audio_features
# 18709          0.000000    0.3610    0.662   97.976  audio_features
#
#                            id                                   uri  \
# 18707  3YB6nCSuFqNiqOvPtAPK9X  spotify:track:3YB6nCSuFqNiqOvPtAPK9X
# 18708  29HSkfe5ITejb0MXhroHtG  spotify:track:29HSkfe5ITejb0MXhroHtG
# 18709  0UBLhedidy1DjSF4ncF5zL  spotify:track:0UBLhedidy1DjSF4ncF5zL
#
#                                               track_href  \
# ...

# %%
check.drop(['type', 'uri', 'track_href', 'analysis_url', 'time_signature', 'danceability_energy_key_loudness_mode_speechiness_acousticness_instrumentalness_liveness_valence_tempo_duration_ms_time_signature'], axis=1, inplace=True)

# %%
check.tail(3)
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 18707         0.673   0.842    1   -10.171     0       0.0304       0.00319
# 18708         0.763   0.419    8    -9.916     0       0.0529       0.38300
# 18709         0.658   0.678    1    -4.407     1       0.0580       0.30300
#
#        instrumentalness  liveness  valence    tempo                      id  \
# 18707          0.000011    0.9520    0.806  134.802  3YB6nCSuFqNiqOvPtAPK9X
# 18708          0.001690    0.0732    0.335   92.044  29HSkfe5ITejb0MXhroHtG
# 18709          0.000000    0.3610    0.662   97.976  0UBLhedidy1DjSF4ncF5zL
#
#        duration_ms
# 18707       241133
# 18708       248591
# 18709       199111

# %%
check.rename(columns={'id':'track_id'}, inplace=True)

# %%
d_merged = ds.merge(check, how='left', on='track_id')

# %%
d_merged.head(3)
# Out:
#                                      title                    artist  \
# 0                                  Starboy     The Weeknd, Daft Punk
# 1  Rockabye (feat. Sean Paul & Anne-Marie)              Clean Bandit
# 2                                   Closer  The Chainsmokers, Halsey
#
#                  track_id  danceability  energy  key  loudness  mode  \
# 0  5aAx2yezTd8zXrkmtKl66Z         0.681   0.594    7    -7.028     1
# 1  5knuzwU65gJK7IF5yJsuaW         0.720   0.763    9    -4.068     0
# 2  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524    8    -5.599     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.2820         0.165          0.000003     0.134    0.535  186.054
# 1       0.0523         0.406          0.000000     0.180    0.742  101.965
# 2       0.0338         0.414          0.000000     0.111    0.661   95.010
#
#    duration_ms
# 0       230453
# 1       251088
# 2       244960

# %%
d_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18710 entries, 0 to 18709
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             18710 non-null  object
#  1   artist            18710 non-null  object
#  2   track_id          18710 non-null  object
#  3   danceability      18710 non-null  float64
#  4   energy            18710 non-null  float64
#  5   key               18710 non-null  int64
#  6   loudness          18710 non-null  float64
#  7   mode              18710 non-null  int64
#  8   speechiness       18710 non-null  float64
#  9   acousticness      18710 non-null  float64
#  10  instrumentalness  18710 non-null  float64
#  11  liveness          18710 non-null  float64
#  12  valence           18710 non-null  float64
#  13  tempo             18710 non-null  float64
#  14  duration_ms       18710 non-null  int64
# dtypes: float64(9), int64(3), object(3)
# ...

# %%
save(d_merged)
# Out:
# /Users/inthesea/Downloads/df.csv

# %%
t01 = pd.read_csv('data/tracks_01.csv', header=0, index_col=False)
t02 = pd.read_csv('data/tracks_02.csv', header=0, index_col=False)
t03 = pd.read_csv('data/tracks_03.csv', header=0, index_col=False)
t04 = pd.read_csv('data/tracks_04.csv', header=0, index_col=False)
t05 = pd.read_csv('data/tracks_05.csv', header=0, index_col=False)
t06 = pd.read_csv('data/tracks_06.csv', header=0, index_col=False)
t07 = pd.read_csv('data/tracks_07.csv', header=0, index_col=False)
t08 = pd.read_csv('data/tracks_08.csv', header=0, index_col=False)
t09 = pd.read_csv('data/tracks_09.csv', header=0, index_col=False)
t10 = pd.read_csv('data/tracks_10.csv', header=0, index_col=False)
t11 = pd.read_csv('data/tracks_11.csv', header=0, index_col=False)
t12 = pd.read_csv('data/tracks_12.csv', header=0, index_col=False)
t13 = pd.read_csv('data/tracks_13.csv', header=0, index_col=False)
t14 = pd.read_csv('data/tracks2_01.csv', header=0, index_col=False)
t15 = pd.read_csv('data/tracks2_02.csv', header=0, index_col=False)
t16 = pd.read_csv('data/tracks2_03.csv', header=0, index_col=False)
t17 = pd.read_csv('data/tracks2_04.csv', header=0, index_col=False)
t18 = pd.read_csv('data/tracks2_05.csv', header=0, index_col=False)
t19 = pd.read_csv('data/tracks2_06.csv', header=0, index_col=False)

# %%
pd.set_option('display.max_columns', None)
t01.head(3)
# Out:
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 1  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 2                                                 []            1
#
#    duration_ms  explicit                                               href  \
# 0       251088     False  https://api.spotify.com/v1/tracks/5knuzwU65gJK...
# 1       161200     False  https://api.spotify.com/v1/tracks/0JiVRyTJcJnm...
# 2       208280     False  https://api.spotify.com/v1/tracks/2nYpbaLykC2c...
#
#                        id  is_local                                     name  \
# 0  5knuzwU65gJK7IF5yJsuaW     False  Rockabye (feat. Sean Paul & Anne-Marie)
# ...

# %%
t01.columns
# Out:
# Index(['artists', 'available_markets', 'disc_number', 'duration_ms',
#        'explicit', 'href', 'id', 'is_local', 'name', 'popularity',
#        'preview_url', 'track_number', 'type', 'uri', 'album_album_type',
#        'album_artists', 'album_available_markets',
#        'album_external_urls_spotify', 'album_href', 'album_id', 'album_images',
#        'album_name', 'album_release_date', 'album_release_date_precision',
#        'album_total_tracks', 'album_type', 'album_uri', 'external_ids_isrc',
#        'external_urls_spotify', 'album', 'release_date_popularity'],
#       dtype='object')

# %%
check2 = pd.concat([t01, t02, t03, t04, t05, t06, t07, t08, t09, t10, t11, t12, t13, t14, t15, t16, t17, t18, t19], ignore_index=True)

# %%
check2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18710 entries, 0 to 18709
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   artists                       18710 non-null  object
#  1   available_markets             18710 non-null  object
#  2   disc_number                   18710 non-null  int64
#  3   duration_ms                   18710 non-null  int64
#  4   explicit                      18710 non-null  bool
#  5   href                          18710 non-null  object
#  6   id                            18710 non-null  object
#  7   is_local                      18710 non-null  bool
#  8   name                          18687 non-null  object
#  9   popularity                    18710 non-null  int64
#  10  preview_url                   8202 non-null   object
#  11  track_number                  18710 non-null  int64
# ...

# %%
check2.tail(3)
# Out:
#                                                  artists  \
# 18707  [{'external_urls': {'spotify': 'https://open.s...
# 18708  [{'external_urls': {'spotify': 'https://open.s...
# 18709  [{'external_urls': {'spotify': 'https://open.s...
#
#                                        available_markets  disc_number  \
# 18707  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
# 18708                                       ['AU', 'NZ']            1
# 18709  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...            1
#
#        duration_ms  explicit  \
# 18707       241133     False
# 18708       248590     False
# 18709       199111     False
#
#                                                     href  \
# 18707  https://api.spotify.com/v1/tracks/3YB6nCSuFqNi...
# 18708  https://api.spotify.com/v1/tracks/29HSkfe5ITej...
# 18709  https://api.spotify.com/v1/tracks/0UBLhedidy1D...
#
#                            id  is_local            name  popularity  \
# ...

# %%
check2.drop(['artists', 'available_markets', 'duration_ms', 'explicit', 'href', 'is_local', 'name', 'preview_url', 'track_number', 'type', 'uri', 'album_album_type', 'album_artists', 
             'album_available_markets', 'album_external_urls_spotify', 'album_href', 'album_id', 'album_images', 'album_total_tracks', 'album_type', 'album_uri', 'external_ids_isrc',
             'external_urls_spotify', 'album', 'release_date_popularity', 'disc_number', 'album_release_date_precision'], axis=1, inplace=True)

# %%
check2.tail(3)
# Out:
#                            id  popularity              album_name  \
# 18707  3YB6nCSuFqNiqOvPtAPK9X          68            Sweet Dreams
# 18708  29HSkfe5ITejb0MXhroHtG          52             Sponge Cake
# 18709  0UBLhedidy1DjSF4ncF5zL          36  New Year's Eve 2017/18
#
#       album_release_date
# 18707         1995-03-11
# 18708         2017-09-29
# 18709         2017-12-22

# %%
check2.rename(columns={'id':'track_id'}, inplace=True)

# %%
check2.tail(3)
# Out:
#                      track_id  popularity              album_name  \
# 18707  3YB6nCSuFqNiqOvPtAPK9X          68            Sweet Dreams
# 18708  29HSkfe5ITejb0MXhroHtG          52             Sponge Cake
# 18709  0UBLhedidy1DjSF4ncF5zL          36  New Year's Eve 2017/18
#
#       album_release_date
# 18707         1995-03-11
# 18708         2017-09-29
# 18709         2017-12-22

# %%
d_merged_2 = d_merged.merge(check2, how='left', on='track_id')

# %%
d_merged_2.head(3)
# Out:
#                                      title                    artist  \
# 0                                  Starboy     The Weeknd, Daft Punk
# 1  Rockabye (feat. Sean Paul & Anne-Marie)              Clean Bandit
# 2                                   Closer  The Chainsmokers, Halsey
#
#                  track_id  danceability  energy  key  loudness  mode  \
# 0  5aAx2yezTd8zXrkmtKl66Z         0.681   0.594    7    -7.028     1
# 1  5knuzwU65gJK7IF5yJsuaW         0.720   0.763    9    -4.068     0
# 2  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524    8    -5.599     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.2820         0.165          0.000003     0.134    0.535  186.054
# 1       0.0523         0.406          0.000000     0.180    0.742  101.965
# 2       0.0338         0.414          0.000000     0.111    0.661   95.010
#
#    duration_ms  popularity                               album_name  \
# ...

# %%
d_merged_2.tail(3)
# Out:
#                   title                                             artist  \
# 18707  Too Much Jewelry                                              Migos
# 18708      Be About You                                  Winston Surfshirt
# 18709    All Falls Down  Alan Walker, Noah Cyrus, Digital Farm Animals,...
#
#                      track_id  danceability  energy  key  loudness  mode  \
# 18707  4loAa1lBkE83qJXU1ddmCV         0.683   0.329    1    -9.155     0
# 18708  29HSkfe5ITejb0MXhroHtG         0.763   0.419    8    -9.916     0
# 18709  0UBLhedidy1DjSF4ncF5zL         0.658   0.678    1    -4.407     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 18707       0.1230         0.214          0.000004    0.1270    0.229
# 18708       0.0529         0.383          0.001690    0.0732    0.335
# 18709       0.0580         0.303          0.000000    0.3610    0.662
#
#          tempo  duration_ms  popularity              album_name  \
# ...

# %%
d_merged_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18710 entries, 0 to 18709
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               18710 non-null  object
#  1   artist              18710 non-null  object
#  2   track_id            18710 non-null  object
#  3   danceability        18710 non-null  float64
#  4   energy              18710 non-null  float64
#  5   key                 18710 non-null  int64
#  6   loudness            18710 non-null  float64
#  7   mode                18710 non-null  int64
#  8   speechiness         18710 non-null  float64
#  9   acousticness        18710 non-null  float64
#  10  instrumentalness    18710 non-null  float64
#  11  liveness            18710 non-null  float64
#  12  valence             18710 non-null  float64
#  13  tempo               18710 non-null  float64
#  14  duration_ms         18710 non-null  int64
# ...

# %%
save(d_merged_2)
# Out:
# /Users/inthesea/Downloads/df.csv
